# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
'''
Exploratory Data Analysis (EDA) is an approach to analyzing datasets to summarize their main characteristics,
often employing statistical and visualization methods. 
It's a crucial initial step in the data analysis processthat helps analysts and data scientists understand the data and 
its underlying structure before applying more complex statistical models or machine learning algorithms.
EDA aims to uncover patterns, relationships, anomalies, and insights within the data.
Overall, EDA is a critical phase in understanding the nature and characteristics of the data, guiding subsequent steps in analysis, and 
ultimately ensuring that the conclusions drawn from the data are reliable and valid. 
It's a flexible and creative process that involves a combination of statistical methods, visualizations, and 
domain knowledge to extract meaningful information from the data.
'''

# %% [markdown]
# Steps

# %%
'''
In exploratory data analysis (EDA), data can be categorized into various types based on the nature of the information they represent. 
The two primary categories are:

Numerical Data:
    Numerical data consists of quantitative information represented by numbers. This category can further be divided into two subtypes:

Continuous Data: These are measurements that can take on any value within a certain range. 
    Discrete Data: These are distinct and separate values that usually represent counts or whole numbers. 
Categorical Data:
    Categorical data consists of qualitative information that represents categories or groups. 

Nominal Data: This represents categories without any specific order or ranking. Examples include gender, colors, types of cars, etc.
Ordinal Data: These categories have a specific order or ranking. 
    Examples include education levels (like high school, bachelor's, master's, etc.) or ratings (such as "low," "medium," "high").
'''

# %%
'''
EDA: Explotatory Data Analysis - Understanding what is there inside the data

Iteration-1:

1. Read the data
2. Shape of data
3. Information about the data
4. Finding duplicate rows, drop duplicate rows
5. Find the basic statistics of continuous data columns
6. Rename the columns(optional)
7. Find the missing values(percentage optional)
8. Finding basic statistics of categorical columns
9. Basic count analysis on categorical columns
(we have )
Iteration 02:
1.Univariate Analysis
2.Target column Univariate analysis
3.Rest of the categorical columns
4.Numerical columns
'''

# %%
'''
kinds of plots
1.Univariate analysis- Categorical variable- Count plot - percentages - pie chart
2. Univariate analysis - numerical variable - boxplot,histogram with kde
3.Multivariate analysis - Categorical,Numerical-boxplot and histplot,kdeplot
4.Multivariate analysis - Categorical,categorical
5.Multivariate analysis - Numerical, Numerical
'''

# %%
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/eda-project-analyze-us-citizens/adult_eda.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
#finding duplicate rows
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# Name: count, dtype: int64

# %%
#drop duplicate rows
df=df.drop_duplicates()
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32537 rows x 15 columns]

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32537.000000  3.253700e+04   31735.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.084008   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.575060   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#finding columns
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
#Rename the columns--replacing - with _
df.columns=df.columns.str.replace('-','_')
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
na=df.isnull()

# %%
df1=df.dropna()
df1
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors           13.0
# 1       50  Self-emp-not-inc   83311     Bachelors           13.0
# 2       38           Private  215646       HS-grad            9.0
# 3       53           Private  234721          11th            7.0
# 4       28           Private  338409     Bachelors           13.0
# ...    ...               ...     ...           ...            ...
# 32555   22           Private  310152  Some-college           10.0
# 32556   27           Private  257302    Assoc-acdm           12.0
# 32557   40           Private  154374       HS-grad            9.0
# 32558   58           Private  151910       HS-grad            9.0
# 32560   52      Self-emp-inc  287927       HS-grad            9.0
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32555       Never-married    Protective-serv  Not-in-family  White    Male
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32555             0             0              40  United-States  <=50K
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [26788 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
#percentage
x=df.isnull().sum()/len(df)*100      #for being more accurate
x
# Out:
# age                0.000000
# workclass          0.000000
# fnlwgt             0.000000
# education          0.000000
# education_num      2.464886
# marital_status     0.000000
# occupation         0.000000
# relationship      15.563820
# race               0.000000
# sex                0.000000
# capital_gain       0.000000
# capital_loss       0.000000
# hours_per_week     0.000000
# native_country     0.000000
# salary             0.000000
# dtype: float64

# %%
100-x         # not null
# Out:
# age               100.000000
# workclass         100.000000
# fnlwgt            100.000000
# education         100.000000
# education_num      97.535114
# marital_status    100.000000
# occupation        100.000000
# relationship       84.436180
# race              100.000000
# sex               100.000000
# capital_gain      100.000000
# capital_loss      100.000000
# hours_per_week    100.000000
# native_country    100.000000
# salary            100.000000
# dtype: float64

# %%
df.notnull()
# Out:
#         age  workclass  fnlwgt  education  education_num  marital_status  \
# 0      True       True    True       True           True            True
# 1      True       True    True       True           True            True
# 2      True       True    True       True           True            True
# 3      True       True    True       True           True            True
# 4      True       True    True       True           True            True
# ...     ...        ...     ...        ...            ...             ...
# 32556  True       True    True       True           True            True
# 32557  True       True    True       True           True            True
# 32558  True       True    True       True           True            True
# 32559  True       True    True       True           True            True
# 32560  True       True    True       True           True            True
#
#        occupation  relationship  race   sex  capital_gain  capital_loss  \
# 0            True          True  True  True          True          True
# 1            True          True  True  True          True          True
# 2            True          True  True  True          True          True
# 3            True          True  True  True          True          True
# 4            True          True  True  True          True          True
# ...           ...           ...   ...   ...           ...           ...
# 32556        True          True  True  True          True          True
# 32557        True          True  True  True          True          True
# 32558        True          True  True  True          True          True
# 32559        True         False  True  True          True          True
# 32560        True          True  True  True          True          True
#
#        hours_per_week  native_country  salary
# 0                True            True    True
# 1                True            True    True
# 2                True            True    True
# 3                True            True    True
# 4                True            True    True
# ...               ...             ...     ...
# 32556            True            True    True
# 32557            True            True    True
# 32558            True            True    True
# 32559            True            True    True
# 32560            True            True    True
#
# [32537 rows x 15 columns]

# %%
df.notnull().sum()
# Out:
# age               32537
# workclass         32537
# fnlwgt            32537
# education         32537
# education_num     31735
# marital_status    32537
# occupation        32537
# relationship      27473
# race              32537
# sex               32537
# capital_gain      32537
# capital_loss      32537
# hours_per_week    32537
# native_country    32537
# salary            32537
# dtype: int64

# %%
n=df.notnull().sum()/len(df)*100
n
# Out:
# age               100.000000
# workclass         100.000000
# fnlwgt            100.000000
# education         100.000000
# education_num      97.535114
# marital_status    100.000000
# occupation        100.000000
# relationship       84.436180
# race              100.000000
# sex               100.000000
# capital_gain      100.000000
# capital_loss      100.000000
# hours_per_week    100.000000
# native_country    100.000000
# salary            100.000000
# dtype: float64

# %%
df.describe(include='object')
#'''
#Out of 32,537 datapoints 22,673 data points have workclass as private
#Unique how many unique words are there in workclass
#'''
# Out:
#        workclass education      marital_status      occupation relationship  \
# count      32537     32537               32537           32537        27473
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22673     10494               14970            4136        13187
#
#          race    sex native_country salary
# count   32537  32537          32537  32537
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27795  21775          29153  24698

# %%
print(df.columns)
categorical_cols = ['workclass','education','marital_status', 'occupation', 'relationship', 'race', 'sex','native_country','salary']

for i in categorical_cols:
    print(f'Columns Name : {i}')
    print(df[i].value_counts())
    print('==========================================')
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')
# Columns Name : workclass
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
# ==========================================
# Columns Name : education
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: count, dtype: int64
# ==========================================
# Columns Name : marital_status
# marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64
# ==========================================
# Columns Name : occupation
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64
# ==========================================
# Columns Name : relationship
# relationship
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64
# ==========================================
# Columns Name : race
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64
# ==========================================
# Columns Name : sex
# sex
# Male      21775
# Female    10762
# Name: count, dtype: int64
# ==========================================
# Columns Name : native_country
# native_country
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64
# ==========================================
# Columns Name : salary
# salary
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64
# ==========================================

# %%
#Check if the Dataset has any Question Mark "?"

print((df.astype(str)=='?').any())
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %%
df=df.replace('?',pd.NA)
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32537 rows x 15 columns]

# %%
(df.astype(str)=='?').any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country    False
# salary            False
# dtype: bool

# %%
df= df.dropna()
df
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors           13.0
# 1       50  Self-emp-not-inc   83311     Bachelors           13.0
# 2       38           Private  215646       HS-grad            9.0
# 3       53           Private  234721          11th            7.0
# 4       28           Private  338409     Bachelors           13.0
# ...    ...               ...     ...           ...            ...
# 32555   22           Private  310152  Some-college           10.0
# 32556   27           Private  257302    Assoc-acdm           12.0
# 32557   40           Private  154374       HS-grad            9.0
# 32558   58           Private  151910       HS-grad            9.0
# 32560   52      Self-emp-inc  287927       HS-grad            9.0
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32555       Never-married    Protective-serv  Not-in-family  White    Male
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32555             0             0              40  United-States  <=50K
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [25035 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# salary            0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
'''
Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) 
separetly from different aspects according to target feature.
'''
# Out:
# '\nExamine all features (first target feature("salary"), then numeric ones, lastly categoric ones) \nseparetly from different aspects according to target feature.\n'

# %%
'''
Salary (Target Feature)
Check the count of person in each "salary" levels and visualize it with a countplot
'''
df
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors           13.0
# 1       50  Self-emp-not-inc   83311     Bachelors           13.0
# 2       38           Private  215646       HS-grad            9.0
# 3       53           Private  234721          11th            7.0
# 4       28           Private  338409     Bachelors           13.0
# ...    ...               ...     ...           ...            ...
# 32555   22           Private  310152  Some-college           10.0
# 32556   27           Private  257302    Assoc-acdm           12.0
# 32557   40           Private  154374       HS-grad            9.0
# 32558   58           Private  151910       HS-grad            9.0
# 32560   52      Self-emp-inc  287927       HS-grad            9.0
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32555       Never-married    Protective-serv  Not-in-family  White    Male
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32555             0             0              40  United-States  <=50K
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [25035 rows x 15 columns]

# %%
df['salary'].value_counts()
# Out:
# salary
# <=50K    17785
# >50K      7250
# Name: count, dtype: int64

# %%
'''
matplotlib.pyplot is a plotting library used for creating visualizations like line plots, bar charts, histograms, etc.
as plt is an alias that allows you to refer to matplotlib.pyplot as plt, 
## import seaborn as sns -- Seaborn is also a data visualization library in Python built on top of Matplotlib. 
   It provides a high-level interface for creating attractive and informative statistical graphics.
'''
import matplotlib.pyplot as plt  # plots are not visually good but used for some settings
import seaborn as sns           # plots are graphically good 

## set the figure size

plt.figure(figsize=(10,5))    # 10 is length 5 is breadth i.e, to describe the size of plot

ax = sns.countplot(x='salary',data=df)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.3,p.get_height()+100),fontsize=10)
    # annotate means writing something at the top
    #get_height gives height and get_x gives position

# %% [markdown]
# # Check the percentage of person in each "salary" levels and visualize it with a pieplot

# %%
percentage = df['salary'].value_counts()/len(df)
percentage
# Out:
# salary
# <=50K    0.710405
# >50K     0.289595
# Name: count, dtype: float64

# %%
plt.pie(percentage)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fe7792a0>,
#   <matplotlib.patches.Wedge at 0x7ab7fe73f3a0>],
#  [Text(-0.6753042144023012, 0.8683111297285616, ''),
#   Text(0.675304133105143, -0.8683111929551015, '')])

# %%
plt.pie(percentage,labels = ['<=50k','>50k'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fe7b77c0>,
#   <matplotlib.patches.Wedge at 0x7ab7fe7b76d0>],
#  [Text(-0.6753042144023012, 0.8683111297285616, '<=50k'),
#   Text(0.675304133105143, -0.8683111929551015, '>50k')])

# %%
plt.pie(percentage,labels = ['<=50k','>50k'],autopct = '%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fe811d80>,
#   <matplotlib.patches.Wedge at 0x7ab7fe811c90>],
#  [Text(-0.6753042144023012, 0.8683111297285616, '<=50k'),
#   Text(0.675304133105143, -0.8683111929551015, '>50k')],
#  [Text(-0.3683477533103461, 0.47362425257921537, '71.0%'),
#   Text(0.3683477089664416, -0.47362428706641896, '29.0%')])

# %%
plt.pie(percentage,labels = ['<=50k','>50k'],autopct = '%.1f%%',explode=[0,0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fe67ca90>,
#   <matplotlib.patches.Wedge at 0x7ab7fe67c9a0>],
#  [Text(-0.6753042144023012, 0.8683111297285616, '<=50k'),
#   Text(0.7366954179328833, -0.947248574132838, '>50k')],
#  [Text(-0.3683477533103461, 0.47362425257921537, '71.0%'),
#   Text(0.42973899379418184, -0.5525616682441554, '29.0%')])

# %%
plt.pie(percentage,labels = ['<=50k','>50k'],autopct = '%.1f%%',explode=[0,0.1],
       colors = ['lightskyblue','gold'],shadow=True)
plt.title("Pie chart of salary",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Pie chart of salary')

# %%
'''
CONCLUSION: 71.0% People's salaries are <=50k, and 29.0% people's salaries are >50k
'''
# Out:
# "\nCONCLUSION: 71.0% People's salaries are <=50k, and 29.0% people's salaries are >50k\n"

# %% [markdown]
# # Numeric Features

# %%
## age
plt.figure(figsize=(10,5))
sns.boxplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
sns.histplot(x='age',data=df,kde=True,bins=20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['age'].describe()
# Out:
# count    25035.000000
# mean        40.741841
# std         12.453234
# min         17.000000
# 25%         31.000000
# 50%         39.000000
# 75%         49.000000
# max         90.000000
# Name: age, dtype: float64

# %%
# check the boxplot and histplot/kdeplot by 'salary' levels
plt.figure(figsize=(10,5))
sns.boxplot(x='salary',data=df,y='age')
# Out:
# <Axes: xlabel='salary', ylabel='age'>

# %%
# allowing you to visually analyze the distribution of 'age' with respect to different salary levels.

plt.figure(figsize=(10,5))
sns.histplot(x='age',data=df,kde=True,bins=20,hue='salary')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(x='age',hue='salary',fill=True,data=df) #even we can use shade instead of fill, but using fill is good than shade
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
'''
check the statistical values by 'salary' levels
'''
#groupby('salary'): This function call groups the DataFrame df by the unique values present in the 'salary' column.
#Essentially, it creates separate groups of data where each group corresponds to a unique value in the 'salary' column.
#['age']: After grouping by 'salary', this part specifies that we are interested in analyzing the 'age' column within each group.
df.groupby('salary')['age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# salary
# <=50K   17785.0  39.399775  13.003662  17.0  29.0  37.0  48.0  90.0
# >50K     7250.0  44.034069  10.269809  19.0  36.0  43.0  51.0  90.0

# %%
'''
CONCLUSION: The mean and median age of the high-income group is higher than the low-income group. 
            It means the older generation possesses more wealth than the young.
'''
# Out:
# '\nCONCLUSION: The mean and median age of the high-income group is higher than the low-income group. \n            It means the older generation possesses more wealth than the young.\n'

# %%
#fnlwgt
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# chcek the boxplot to see the extreme values

plt.figure(figsize=(10,5))
sns.boxplot(x='fnlwgt',data=df)
# Out:
# <Axes: xlabel='fnlwgt'>

# %%
# check the histplot/kdeplot to see distribution features
plt.figure(figsize=(10,5))
sns.kdeplot(x='fnlwgt',data=df,fill=True)
# Out:
# <Axes: xlabel='fnlwgt', ylabel='Density'>

# %%
# check the boxplot and histplot/kdeplot by 'salary' level
plt.figure(figsize=(10,5))
sns.boxplot(x='fnlwgt',y='salary', data=df)
# Out:
# <Axes: xlabel='fnlwgt', ylabel='salary'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='fnlwgt',data=df,hue='salary',kde=True,bins=20,fill=True)
# Out:
# <Axes: xlabel='fnlwgt', ylabel='Count'>

# %%
# check the statistical values by 'salary' level
df.groupby('salary')['fnlwgt'].describe()
# Out:
#           count           mean            std      min        25%       50%  \
# salary
# <=50K   17785.0  189607.913972  107277.514108  13769.0  115700.00  178472.0
# >50K     7250.0  188242.126897  102631.297061  14878.0  119274.25  176185.5
#
#              75%        max
# salary
# <=50K   240166.0  1484705.0
# >50K    231413.0  1226583.0

# %%
'''
CONCLUSION: There is no significant difference between high and low-income groups according to the "fnlwgt" feature.
'''
# Out:
# '\nCONCLUSION: There is no significant difference between high and low-income groups according to the "fnlwgt" feature.\n'

# %%
#Capital_gain
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
#check the boxplot of capital_gain to see extreme values
plt.figure(figsize=(10,5))
sns.boxplot(x='capital_gain',data=df)
# Out:
# <Axes: xlabel='capital_gain'>

# %%
# check the histplot/kdeplot to see the distribution of feature
plt.figure(figsize=(10,5))
x = sns.histplot(x='capital_gain',data=df,fill=True,bins=20,kde=True)
for i in x.patches:
    x.annotate((i.get_height()),(i.get_x()+0.3,i.get_height()+10))

# %%
#check the statistical values of capital_gain
df.capital_gain.describe()
# Out:
# count    25035.000000
# mean      1264.133773
# std       8016.462887
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital_gain, dtype: float64

# %%
## check the boxplot and histplot/kdeplot by 'salary' levels
plt.figure(figsize=(10,5))
sns.boxplot(x='salary',data=df,y='capital_gain')
# Out:
# <Axes: xlabel='salary', ylabel='capital_gain'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='capital_gain',data=df,hue='salary',kde=True,bins=20,fill=True)
# Out:
# <Axes: xlabel='capital_gain', ylabel='Count'>

# %%
plt.pie(percentage,labels=['male','female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fc2aebf0>,
#   <matplotlib.patches.Wedge at 0x7ab7fbf6abc0>],
#  [Text(-0.6753042144023012, 0.8683111297285616, 'male'),
#   Text(0.675304133105143, -0.8683111929551015, 'female')])

# %%
plt.pie(percentage,labels=['male','female'],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fe53e3b0>,
#   <matplotlib.patches.Wedge at 0x7ab7fe53e4a0>],
#  [Text(-0.6753042144023012, 0.8683111297285616, 'male'),
#   Text(0.675304133105143, -0.8683111929551015, 'female')],
#  [Text(-0.3683477533103461, 0.47362425257921537, '71.0%'),
#   Text(0.3683477089664416, -0.47362428706641896, '29.0%')])

# %%
plt.pie(percentage,labels=['male','female'],autopct='%.1f%%',explode=[0,0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fbde4df0>,
#   <matplotlib.patches.Wedge at 0x7ab7fbde4d00>],
#  [Text(-0.6753042144023012, 0.8683111297285616, 'male'),
#   Text(0.7366954179328833, -0.947248574132838, 'female')],
#  [Text(-0.3683477533103461, 0.47362425257921537, '71.0%'),
#   Text(0.42973899379418184, -0.5525616682441554, '29.0%')])

# %%
plt.pie(percentage,labels=['male','female'],autopct='%.1f%%',explode=[0,0.1],colors=['violet','yellow'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7ab7fbe0f940>,
#   <matplotlib.patches.Wedge at 0x7ab7fbe0f880>],
#  [Text(-0.6753042144023012, 0.8683111297285616, 'male'),
#   Text(0.7366954179328833, -0.947248574132838, 'female')],
#  [Text(-0.3683477533103461, 0.47362425257921537, '71.0%'),
#   Text(0.42973899379418184, -0.5525616682441554, '29.0%')])

# %%
plt.pie(percentage,labels=['male','female'],autopct='%.1f%%',explode=[0,0.1],colors=['violet','yellow'],shadow=True)
plt.title('pie chart of sex',fontsize=15)
# Out:
# Text(0.5, 1.0, 'pie chart of sex')

# %%
#fnlwgt
sns.boxplot(x='fnlwgt',data=df)
# Out:
# <Axes: xlabel='fnlwgt'>

# %%
sns.histplot(x='fnlwgt',data=df,kde=True,bins=8)
# Out:
# <Axes: xlabel='fnlwgt', ylabel='Count'>

# %%
df['fnlwgt'].describe()
# Out:
# count    2.503500e+04
# mean     1.892124e+05
# std      1.059527e+05
# min      1.376900e+04
# 25%      1.168045e+05
# 50%      1.777270e+05
# 75%      2.377350e+05
# max      1.484705e+06
# Name: fnlwgt, dtype: float64

# %%
# race
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,10))
ax=sns.countplot(x='race',data=df)

for i in ax.patches:
    ax.annotate((i.get_height()),(i.get_x()+0.3,i.get_height()+15),fontsize=20)

# %%
percentage=df['race'].value_counts()/len(df)*100
percentage
# Out:
# race
# White                 86.251248
# Black                  9.075295
# Asian-Pac-Islander     2.915918
# Amer-Indian-Eskimo     0.962652
# Other                  0.794887
# Name: count, dtype: float64

# %%
# age vs salary
sns.boxplot(x='age',y='salary',data=df)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
sns.histplot(x='age',data=df,hue='salary',kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(x='age',data=df,hue='salary',shade=True)
# Out:
# /tmp/ipykernel_47/3063441027.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='age',data=df,hue='salary',shade=True)
# <Axes: xlabel='age', ylabel='Density'>

# %%
df.groupby('salary')['age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# salary
# <=50K   17785.0  39.399775  13.003662  17.0  29.0  37.0  48.0  90.0
# >50K     7250.0  44.034069  10.269809  19.0  36.0  43.0  51.0  90.0

# %%
'''
Conclusion: The mean and median age of the height income group is higher than lower income group.It means that older generation
possesses more wealth than young.
'''
# Out:
# '\nConclusion: The mean and median age of the height income group is higher than lower income group.It means that older generation\npossesses more wealth than young.\n'

# %%
fig,ax=plt.subplots(figsize=(12,6))##figure,ax-axes
sns.countplot(x='education',data=df)
ax.set_xticklabels(df['education'].unique(),rotation=45)
# Out:
# [Text(0, 0, 'Bachelors'),
#  Text(1, 0, 'HS-grad'),
#  Text(2, 0, '11th'),
#  Text(3, 0, 'Masters'),
#  Text(4, 0, '9th'),
#  Text(5, 0, 'Some-college'),
#  Text(6, 0, 'Assoc-acdm'),
#  Text(7, 0, '7th-8th'),
#  Text(8, 0, 'Doctorate'),
#  Text(9, 0, 'Assoc-voc'),
#  Text(10, 0, 'Prof-school'),
#  Text(11, 0, '5th-6th'),
#  Text(12, 0, '10th'),
#  Text(13, 0, 'Preschool'),
#  Text(14, 0, '12th'),
#  Text(15, 0, '1st-4th')]

# %%
df.groupby('education')['salary'].value_counts()
# Out:
# education     salary
# 10th          <=50K      574
#               >50K        57
# 11th          <=50K      608
#               >50K        55
# 12th          <=50K      206
#               >50K        29
# 1st-4th       <=50K      128
#               >50K         6
# 5th-6th       <=50K      258
#               >50K        12
# 7th-8th       <=50K      467
#               >50K        35
# 9th           <=50K      356
#               >50K        24
# Assoc-acdm    <=50K      623
#               >50K       248
# Assoc-voc     <=50K      812
#               >50K       330
# Bachelors     <=50K     2400
#               >50K      2051
# Doctorate     >50K       276
#               <=50K       85
# HS-grad       <=50K     6637
#               >50K      1563
# Masters       >50K       890
#               <=50K      645
# Preschool     <=50K       38
# Prof-school   >50K       393
#               <=50K      122
# Some-college  <=50K     3826
#               >50K      1281
# Name: count, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(12,6))
sns.countplot(x='education',data=df,hue='salary')
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
fig,ax=plt.subplots(figsize=(12,6))
sns.countplot(x='education',data=df,hue='salary')
ax.set_xticklabels(df['education'].unique(),rotation=45)
# Out:
# [Text(0, 0, 'Bachelors'),
#  Text(1, 0, 'HS-grad'),
#  Text(2, 0, '11th'),
#  Text(3, 0, 'Masters'),
#  Text(4, 0, '9th'),
#  Text(5, 0, 'Some-college'),
#  Text(6, 0, 'Assoc-acdm'),
#  Text(7, 0, '7th-8th'),
#  Text(8, 0, 'Doctorate'),
#  Text(9, 0, 'Assoc-voc'),
#  Text(10, 0, 'Prof-school'),
#  Text(11, 0, '5th-6th'),
#  Text(12, 0, '10th'),
#  Text(13, 0, 'Preschool'),
#  Text(14, 0, '12th'),
#  Text(15, 0, '1st-4th')]

# %%
'''
If there are lot of categories in the data, you need to consider the process of recategorization
'''

# %%
df['education'].unique()

# %%
def mapping_education(x):
    if x in['5th-6th','10th','1st-4th','preschool','12th','11th','9th','7th-8th']:
        return 'low_level_grade'
    elif x in ['HS-grad','Some-college','Assoc-acdm','Assoc-voc']:
        return'medium_level_grade'
    elif x in['Bachelors','Prof-school','Masters','Doctorate']:
        return'high_level_grade'

# %%
#declare a mapping function and perform apply
df['education_summary']=df['education'].apply(mapping_education)

# %%
sns.countplot(x='education_summary',data=df)

# %%
sns.countplot(x='education_summary',hue='salary',data=df)

# %% [markdown]
# ## Alternative method - PieCharts

# %%
sal=df.groupby('salary')['education_summary'].value_counts().reset_index()

# %%
sal

# %%
sal.table

# %%
sal.table

# %%
df.groupby('salary')['education_summary'].value_counts().reset_index()/df.groupby('salary')['education_summary'].count()
